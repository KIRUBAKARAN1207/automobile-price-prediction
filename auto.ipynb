# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Auto.csv')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
for i in df.columns:
    if df.dtypes[i]=='O':
        print(df[i].unique())
# Out:
# ['?' '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# ['gas' 'diesel']
# ['std' 'turbo']
# ['two' 'four' '?']
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# ['rwd' 'fwd' '4wd']
# ['front' 'rear']
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']
# ['3.47' '2.68' '3.19' '3.13' '3.5' '3.31' '3.62' '2.91' '3.03' '2.97'
# ...

# %%
df.where(df == '?')
# Out:
#      symboling normalized-losses make fuel-type aspiration num-of-doors  \
# 0          NaN                 ?  NaN       NaN        NaN          NaN
# 1          NaN                 ?  NaN       NaN        NaN          NaN
# 2          NaN                 ?  NaN       NaN        NaN          NaN
# 3          NaN               NaN  NaN       NaN        NaN          NaN
# 4          NaN               NaN  NaN       NaN        NaN          NaN
# ..         ...               ...  ...       ...        ...          ...
# 200        NaN               NaN  NaN       NaN        NaN          NaN
# 201        NaN               NaN  NaN       NaN        NaN          NaN
# 202        NaN               NaN  NaN       NaN        NaN          NaN
# 203        NaN               NaN  NaN       NaN        NaN          NaN
# 204        NaN               NaN  NaN       NaN        NaN          NaN
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
df.replace(to_replace ="?",value ="NaN")
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df['normalized-losses'] = pd.to_numeric(df['normalized-losses'], errors='coerce').astype('Int64')

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3               <NA>  alfa-romero       gas        std
# 1            3               <NA>  alfa-romero       gas        std
# 2            1               <NA>  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# 204         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
for i in df.columns:
    if df.dtypes[i]=='O':
        print(df[i].unique())
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# ['gas' 'diesel']
# ['std' 'turbo']
# ['two' 'four' '?']
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# ['rwd' 'fwd' '4wd']
# ['front' 'rear']
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']
# ['3.47' '2.68' '3.19' '3.13' '3.5' '3.31' '3.62' '2.91' '3.03' '2.97'
#  '3.34' '3.6' '2.92' '3.15' '3.43' '3.63' '3.54' '3.08' '?' '3.39' '3.76'
#  '3.58' '3.46' '3.8' '3.78' '3.17' '3.35' '3.59' '2.99' '3.33' '3.7'
#  '3.61' '3.94' '3.74' '2.54' '3.05' '3.27' '3.24' '3.01']
# ['2.68' '3.47' '3.4' '2.8' '3.19' '3.39' '3.03' '3.11' '3.23' '3.46' '3.9'
#  '3.41' '3.07' '3.58' '4.17' '2.76' '3.15' '?' '3.16' '3.64' '3.1' '3.35'
# ...

# %%
df['normalized-losses'].unique()
# Out:
# <IntegerArray>
# [<NA>,  164,  158,  192,  188,  121,   98,   81,  118,  148,  110,  145,  137,
#   101,   78,  106,   85,  107,  104,  113,  150,  129,  115,   93,  142,  161,
#   153,  125,  128,  122,  103,  168,  108,  194,  231,  119,  154,   74,  186,
#    83,  102,   89,   87,   77,   91,  134,   65,  197,   90,   94,  256,   95]
# Length: 52, dtype: Int64

# %%
df['num-of-doors'].where(df['num-of-doors'] == '?')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 200    NaN
# 201    NaN
# 202    NaN
# 203    NaN
# 204    NaN
# Name: num-of-doors, Length: 205, dtype: object

# %%
df['num-of-doors'] == '?'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: num-of-doors, Length: 205, dtype: bool

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce').astype('Int64')
df['peak-rpm'] = pd.to_numeric(df['peak-rpm'], errors='coerce').astype('Int64')
df['price'] = pd.to_numeric(df['price'], errors='coerce').astype('Int64')
df['bore'] = pd.to_numeric(df['bore'], errors='coerce').astype('Float64')
df['stroke'] = pd.to_numeric(df['stroke'], errors='coerce').astype('Float64')

# %%
df['num-of-doors']=df['num-of-doors'].replace('?',None)

# %%
for i in df.columns:
    if df.dtypes[i]=='O':
        print(df[i].unique())
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# ['gas' 'diesel']
# ['std' 'turbo']
# ['two' 'four']
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# ['rwd' 'fwd' '4wd']
# ['front' 'rear']
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']

# %%
df.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
len(df['num-of-doors'])
# Out:
# 205

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.columns=[i.lower().strip('--') for i in df.columns]

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3               <NA>  alfa-romero       gas        std
# 1            3               <NA>  alfa-romero       gas        std
# 2            1               <NA>  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# 204         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split,GridSearchCV
le=LabelEncoder()

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3               <NA>  alfa-romero       gas        std
# 1            3               <NA>  alfa-romero       gas        std
# 2            1               <NA>  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1                 95        volvo       gas        std
# 201         -1                 95        volvo       gas      turbo
# 202         -1                 95        volvo       gas        std
# 203         -1                 95        volvo    diesel      turbo
# 204         -1                 95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
for i in df.columns:
    if df.dtypes[i]=='O':
        df[i]=le.fit_transform(df[i])

# %%
df['num-of-doors'].shape
# Out:
# (205,)

# %%
import fancyimpute
im=fancyimpute.IterativeImputer()
model1=im.fit(df)

# %%
dfim=pd.DataFrame(data=model1.transform(df),columns=df.columns)

# %%
dfim=pd.DataFrame(data=model1.transform(df),columns=df.columns)

# %%
dfim
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0          3.0         221.964481   0.0        1.0         0.0           1.0
# 1          3.0         221.162444   0.0        1.0         0.0           1.0
# 2          1.0         153.818927   0.0        1.0         0.0           1.0
# 3          2.0         164.000000   1.0        1.0         0.0           0.0
# 4          2.0         164.000000   1.0        1.0         0.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200       -1.0          95.000000  21.0        1.0         0.0           0.0
# 201       -1.0          95.000000  21.0        1.0         1.0           0.0
# 202       -1.0          95.000000  21.0        1.0         0.0           0.0
# 203       -1.0          95.000000  21.0        0.0         1.0           0.0
# 204       -1.0          95.000000  21.0        1.0         1.0           0.0
#
# ...

# %%
from pyod.models.knn import KNN

# %%
knn_od=KNN()
out=knn_od.fit(dfim)
dfim['outlier']=out.predict(dfim)
(dfim['outlier'].sum())
# Out:
# 18

# %%
dfim.head(50)
# Out:
#     symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0         3.0         221.964481   0.0        1.0         0.0           1.0
# 1         3.0         221.162444   0.0        1.0         0.0           1.0
# 2         1.0         153.818927   0.0        1.0         0.0           1.0
# 3         2.0         164.000000   1.0        1.0         0.0           0.0
# 4         2.0         164.000000   1.0        1.0         0.0           0.0
# 5         2.0         167.197679   1.0        1.0         0.0           1.0
# 6         1.0         158.000000   1.0        1.0         0.0           0.0
# 7         1.0         150.542569   1.0        1.0         0.0           0.0
# 8         1.0         158.000000   1.0        1.0         1.0           0.0
# 9         0.0         141.523155   1.0        1.0         1.0           1.0
# 10        2.0         192.000000   2.0        1.0         0.0           1.0
# ...

# %%
dfim.drop(dfim[(dfim['outlier']==1)].index,inplace=True)

# %%
dfim.head(50)
# Out:
#     symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0         3.0         221.964481   0.0        1.0         0.0           1.0
# 1         3.0         221.162444   0.0        1.0         0.0           1.0
# 2         1.0         153.818927   0.0        1.0         0.0           1.0
# 3         2.0         164.000000   1.0        1.0         0.0           0.0
# 4         2.0         164.000000   1.0        1.0         0.0           0.0
# 5         2.0         167.197679   1.0        1.0         0.0           1.0
# 6         1.0         158.000000   1.0        1.0         0.0           0.0
# 7         1.0         150.542569   1.0        1.0         0.0           0.0
# 9         0.0         141.523155   1.0        1.0         1.0           1.0
# 10        2.0         192.000000   2.0        1.0         0.0           1.0
# 11        0.0         192.000000   2.0        1.0         0.0           0.0
# ...

# %%
dfim.drop('outlier',axis=1,inplace=True)

# %%
dfim
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0          3.0         221.964481   0.0        1.0         0.0           1.0
# 1          3.0         221.162444   0.0        1.0         0.0           1.0
# 2          1.0         153.818927   0.0        1.0         0.0           1.0
# 3          2.0         164.000000   1.0        1.0         0.0           0.0
# 4          2.0         164.000000   1.0        1.0         0.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200       -1.0          95.000000  21.0        1.0         0.0           0.0
# 201       -1.0          95.000000  21.0        1.0         1.0           0.0
# 202       -1.0          95.000000  21.0        1.0         0.0           0.0
# 203       -1.0          95.000000  21.0        0.0         1.0           0.0
# 204       -1.0          95.000000  21.0        1.0         1.0           0.0
#
# ...

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(dfim.horsepower,dfim.price)
# Out:
# c:\Users\KIRUBA KARAN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
x=dfim.iloc[:,:-1]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          187 non-null    float64
#  1   normalized-losses  187 non-null    float64
#  2   make               187 non-null    float64
#  3   fuel-type          187 non-null    float64
#  4   aspiration         187 non-null    float64
#  5   num-of-doors       187 non-null    float64
#  6   body-style         187 non-null    float64
#  7   drive-wheels       187 non-null    float64
#  8   engine-location    187 non-null    float64
#  9   wheel-base         187 non-null    float64
#  10  length             187 non-null    float64
#  11  width              187 non-null    float64
#  12  height             187 non-null    float64
#  13  curb-weight        187 non-null    float64
#  14  engine-type        187 non-null    float64
# ...

# %%
len(dfim['normalized-losses'].unique())
# Out:
# 79

# %%
dfim.head(4)
# Out:
#    symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0        3.0         221.964481   0.0        1.0         0.0           1.0
# 1        3.0         221.162444   0.0        1.0         0.0           1.0
# 2        1.0         153.818927   0.0        1.0         0.0           1.0
# 3        2.0         164.000000   1.0        1.0         0.0           0.0
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0         0.0           2.0              0.0        88.6  ...        130.0
# 1         0.0           2.0              0.0        88.6  ...        130.0
# 2         2.0           2.0              0.0        94.5  ...        152.0
# 3         3.0           1.0              0.0        99.8  ...        109.0
#
#    fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0          5.0  3.47    2.68                9.0       111.0    5000.0
# 1          5.0  3.47    2.68                9.0       111.0    5000.0
# ...

# %%
x
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0          3.0         221.964481   0.0        1.0         0.0           1.0
# 1          3.0         221.162444   0.0        1.0         0.0           1.0
# 2          1.0         153.818927   0.0        1.0         0.0           1.0
# 3          2.0         164.000000   1.0        1.0         0.0           0.0
# 4          2.0         164.000000   1.0        1.0         0.0           0.0
# ..         ...                ...   ...        ...         ...           ...
# 200       -1.0          95.000000  21.0        1.0         0.0           0.0
# 201       -1.0          95.000000  21.0        1.0         1.0           0.0
# 202       -1.0          95.000000  21.0        1.0         0.0           0.0
# 203       -1.0          95.000000  21.0        0.0         1.0           0.0
# 204       -1.0          95.000000  21.0        1.0         1.0           0.0
#
# ...

# %%
len(dfim['num-of-doors'].unique())
# Out:
# 2

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
c=[]
b=[]
for j in dfim.iloc[:,:-1].columns:
    if len(dfim[j].unique())<10:
        c.append(j)
    else:
        b.append(j)

# %%
len(b)
# Out:
# 15

# %%
len(dfim.make.unique())
# Out:
# 21

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[0]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[1]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[2]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[3]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[4]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[5]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[6]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[7]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[8]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.scatterplot(dfim[b[0]],dfim['price'],hue=dfim[c[9]])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='price'>

# %%
sns.kdeplot(dfim['normalized-losses'])
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='Density'>

# %%
xtrain,xtest,ytrain,ytest=train_test_split(dfim.iloc[:,:-1],dfim.iloc[:,-1],test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.ensemble import BaggingRegressor,RandomForestRegressor
br,rr=BaggingRegressor(),RandomForestRegressor()
from sklearn.tree import DecisionTreeRegressor
dr=DecisionTreeRegressor()
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
reg={}
for i in (lr,br,rr,dr,knn):
    reg['models_%s'%i]=i.fit(xtrain,ytrain)
    print('score value for train for %s is %f'%(i,i.score(xtrain,ytrain)))
    print('score value for test for %s is %f'%(i,i.score(xtest,ytest)))
    print('R2_Score for test %s is %f'%(i,r2_score(ytest,i.predict(xtest))))
    print('\n')
# Out:
# score value for train for LinearRegression() is 0.872844
# score value for test for LinearRegression() is 0.741156
# R2_Score for test LinearRegression() is 0.741156
#
#
# score value for train for BaggingRegressor() is 0.958498
# score value for test for BaggingRegressor() is 0.706486
# R2_Score for test BaggingRegressor() is 0.706486
#
#
# score value for train for RandomForestRegressor() is 0.973054
# score value for test for RandomForestRegressor() is 0.741443
# R2_Score for test RandomForestRegressor() is 0.741443
#
#
# score value for train for DecisionTreeRegressor() is 0.999864
# score value for test for DecisionTreeRegressor() is 0.720793
# R2_Score for test DecisionTreeRegressor() is 0.720793
#
#
# score value for train for KNeighborsRegressor() is 0.794174
# score value for test for KNeighborsRegressor() is 0.661803
# R2_Score for test KNeighborsRegressor() is 0.661803

# %%
len(rr.estimators_)
# Out:
# 100

# %%
reg.keys()
# Out:
# dict_keys(['models_LinearRegression()', 'models_BaggingRegressor()', 'models_RandomForestRegressor()', 'models_DecisionTreeRegressor()', 'models_KNeighborsRegressor()'])

# %% [markdown]
# # where from the above result its is declared that random forest regressor works better
